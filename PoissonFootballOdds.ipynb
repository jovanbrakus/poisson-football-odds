# %%
from poissonodds.loader import fetch_season_data, ENGLAND_PREMIER_LEAGUE, ITALY_SERIE_A, SEASON_2016_2017
from poissonodds.odds import match_odds_poisson, complete_odds

# %% [markdown]
# Fixture data is loaded from http://football-data.co.uk.
# Premier League 2016/2017 data is available at http://www.football-data.co.uk/mmz4281/1617/E0.csv

# %%
season_data = fetch_season_data(SEASON_2016_2017, ENGLAND_PREMIER_LEAGUE)

# %%
season_data.head()
# Out:
#   Div      Date        HomeTeam    AwayTeam  FTHG  FTAG FTR  HTHG  HTAG HTR  \
# 0  E0  13/08/16         Burnley     Swansea     0     1   A     0     0   D
# 1  E0  13/08/16  Crystal Palace   West Brom     0     1   A     0     0   D
# 2  E0  13/08/16         Everton   Tottenham     1     1   D     1     0   H
# 3  E0  13/08/16            Hull   Leicester     2     1   H     1     0   H
# 4  E0  13/08/16        Man City  Sunderland     2     1   H     1     0   H
#
#    ...   BbAv<2.5  BbAH  BbAHh  BbMxAHH  BbAvAHH  BbMxAHA  BbAvAHA  PSCH  \
# 0  ...       1.61    32  -0.25     2.13     2.06     1.86     1.81  2.79
# 1  ...       1.52    33  -0.50     2.07     2.00     1.90     1.85  2.25
# 2  ...       1.77    32   0.25     1.91     1.85     2.09     2.00  3.64
# 3  ...       1.67    31   0.25     2.35     2.26     2.03     1.67  4.68
# 4  ...       2.48    34  -1.50     1.81     1.73     2.20     2.14  1.25
#
#    PSCD   PSCA
# 0  3.16   2.89
# 1  3.15   3.86
# 2  3.54   2.16
# ...

# %%
match_odds_poisson(season_data, 'Arsenal', 'Liverpool')
# Out:
#   HomeTeam   AwayTeam   HomeWin   AwayWin     Draw
# 0  Arsenal  Liverpool  0.451632  0.330237  0.21083

# %%
complete_odds(season_data)
# Out:
#         HomeTeam        AwayTeam   HomeWin   AwayWin      Draw
# 0    Southampton        West Ham  0.228709  0.506153  0.264259
# 1    Southampton     Bournemouth  0.302132  0.385566  0.312146
# 2    Southampton         Swansea  0.323650  0.352132  0.324117
# 3    Southampton         Chelsea  0.213169  0.532952  0.252598
# 4    Southampton      Sunderland  0.383810  0.263035  0.353105
# 5    Southampton       Liverpool  0.191713  0.570609  0.235525
# 6    Southampton       Leicester  0.334934  0.334934  0.330048
# 7    Southampton        Man City  0.134018  0.673976  0.183340
# 8    Southampton         Burnley  0.383810  0.263035  0.353105
# 9    Southampton         Arsenal  0.160422  0.626562  0.208440
# 10   Southampton  Crystal Palace  0.245309  0.478007  0.276097
# 11   Southampton   Middlesbrough  0.424687  0.205995  0.369274
# 12   Southampton         Watford  0.358604  0.299598  0.341737
# 13   Southampton            Hull  0.439175  0.186426  0.374357
# ...
